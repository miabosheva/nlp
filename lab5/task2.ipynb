# %%
from datasets import load_dataset
import torch
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from datasets import load_dataset
from transformers import BertTokenizerFast, TFBertModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import random

# %%
dataset = load_dataset("commonsense_qa")
# Out:
# Using the latest cached version of the module from C:\Users\Mia\.cache\huggingface\modules\datasets_modules\datasets\commonsense_qa\28d68f56649a7f0c23bc68eae850af914aa03f95f810011ae8cf58cc5ff5051b (last modified on Mon Dec 25 12:04:23 2023) since it couldn't be found locally at commonsense_qa., or remotely on the Hugging Face Hub.
# Found cached dataset commonsense_qa (C:/Users/Mia/.cache/huggingface/datasets/commonsense_qa/default/1.0.0/28d68f56649a7f0c23bc68eae850af914aa03f95f810011ae8cf58cc5ff5051b)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
generics_kb = load_dataset("generics_kb", "generics_kb")
# Out:
# Using the latest cached version of the module from C:\Users\Mia\.cache\huggingface\modules\datasets_modules\datasets\generics_kb\9b41cde494db24f842a9260588bcfb2e3a257364568666ef240e98c70fb0e709 (last modified on Wed Jan 10 14:22:24 2024) since it couldn't be found locally at generics_kb., or remotely on the Hugging Face Hub.
# Found cached dataset generics_kb (C:/Users/Mia/.cache/huggingface/datasets/generics_kb/generics_kb/1.0.0/9b41cde494db24f842a9260588bcfb2e3a257364568666ef240e98c70fb0e709)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_ds = dataset['train'][:5000]
test_ds = dataset['test']
val_ds = dataset['validation']

# %%
questions = train_ds['question']
choices = [choice['text'] for choice in train_ds['choices']]
answers = train_ds['answerKey']

# %%
kb_sentences = generics_kb['train']['generic_sentence']

# %%
# decrease the size of the knowledge base to speed up encoding
kb_sentences = random.sample(kb_sentences, 1000)

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')

# %%
len(kb_sentences)
# Out:
# 1000

# %%
max_len = 27

# %%
knowledge_base_tokens = [tokenizer.encode(sentence, return_tensors='pt')[0] for sentence in kb_sentences]

# %%
knowledge_base_tokens_padded = torch.stack([
    torch.nn.functional.pad(token, (0, max_len - len(token)))
    for token in knowledge_base_tokens
])

# %%
def convert_answer_for_index(i, ds):
    answer_index = ord(ds['answerKey'][i]) - ord('A')
    return ds['choices'][i]['text'][answer_index]

# %% [markdown]
# Tried different methods for semantic similarity, but found that cosine similarity works just as well but faster in this case. Because I am working with a smaller dataset of the knowledge base, the sentences dont have a big semantic similarity for humans. I tried:
# - spaCy's similarity method
# - cosine similarity from sentence transformers, util package

# %%
sentences_merged = []
for i in range(len(questions)):
    question = questions[i]
    choices_i = choices[i]

    question_tokens = tokenizer.encode(question, return_tensors='pt')[0]
    question_tokens = torch.nn.functional.pad(question_tokens, (0, max_len - len(question_tokens)))

    similarities = [cosine_similarity(question_tokens.detach().reshape(1, -1).numpy(), kb_token.reshape(1, -1).detach().numpy())[0][0] for kb_token in knowledge_base_tokens_padded]

    most_similar_indexes = np.argsort(similarities)[-3:]
    most_similar_indexes = [int(x) for x in most_similar_indexes]

    input_text = f"{question}"+" ".join([kb_sentences[i] for i in most_similar_indexes])
    print(input_text)

    sentences_merged.append(input_text)
# Out:
# The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?Significant discounts are available for customers ordering more than two reports per year. Larval management is the key to mosquito control. Video tapes are due before the center closes on the day following checkout.
# Where would you expect to find a pizzeria while shopping?Lights dim or blink and electronic systems misoperate. Grants are performance-based with costs reimbursed upon successful completion of a training program. Front lawn is often the scene of impromtu ball games.
# When eating everything on the tasting menu, what does one tend to feel?History is a difficult and subtle craft. Living room has two queen sleeper sofas. Special emphasis is given to collaborative projects with leading research groups worldwide.
# What does playing soccer for a long time lead to?Life is so beautiful when it is kept simple. Length is considereable more trustable than start. Some people are afraid of a name like that.
# Which entrance would you use if you do not want to use the back entrance?Representatives are generally from environmental staff or management, but anyone is free to join. Some reviews take even longer, compared to an average of six to eight months in Europe. Good questions ask who, what, when, where, why, and how.
# You can share files with someone if you have a connection to a what?Soldiers can keep firing while remaining mobile, effective and safe. Many people are desperate to change themselves and to change the world. Plants also remove greenhouse gas from the air, provide habitat to many animals.
# The accelerator was controller via a hand throttle, and the foot pedals controlled the steering in the small what?Many museums also have a specific fund solely for the purchase or care of items in the collection. Significant discounts are available for customers ordering more than two reports per year. Video tapes are due before the center closes on the day following checkout.
# Sean was lying about the body, but he was very scared.  He constantly worried about what?Latest price offers, press releases, news and information all keep a site interesting. Sites are accessible either by country or by subject .This service maintained by Asia Online . Mantles lean against the walls all kinds and varieties looking stranded and forlorn.
# The drug kingpin told his man to run errands, this was code to go to all the dealers to do what they had?Some applications make multiple passes over the application data before determining a final result. Car Talk revisits some of the more interesting callers from past shows. Academic standing is reviewed at the end of each spring semester.
# Though he could've kept going his body appreciated the rest, it had been constantly what during the day?Corporate responsibility is about to be replaced by individual accountability. Residents are responsible for any damage caused by such decorations. Accommodation is in single, twin or triple study bedrooms on campus, all with washbasins.
# Too many people want exotic snakes.  The demand is driving what to carry them?Internet providers charge the insurers significantly less than offline agents. People are kind in offering advice on what to do. Every cell is an electrical generator, and produces an electrical field.
# Joe suffered many consequences from stabbing a stranger to death.   Among them, the family of the victim did something to him. What was that?Site includes industry news and applicable information. Care is individualized and utilizes the most current treatment methods. Development is behind normal and insect pressure is significant.
# To prevent any glare during the big football game he made sure to clean the dust of his what?Plants also remove greenhouse gas from the air, provide habitat to many animals. Freedom is the noblest pay For the true man's toil. People begin to regain their own sense of self identity, self respect and personal integrity.
# I have something in my head I want to share, what ways can I do that?Fields are too wet in most areas that had rain over the weekend. Some reviews take even longer, compared to an average of six to eight months in Europe. Many children have both speech and language problems while others have only speech problems.
# He wanted a house that was gated off from other places, where should he start looking?Students fold the paper into three columns and select one of the problems from the chapter to solve. Links are to a page with geographical and historical details about the country's time zones. Some reviews take even longer, compared to an average of six to eight months in Europe.
# Where in Southern Europe would you find many canals?Results appear in the second table where running totals are also kept. Students gain exposure to a wide variety of substantive law. Someone has to show the youth that someone cares.
# What would a camper need to do before he or she can start cooking food?Smokers are at much greater risk from radon in air than nonsmokers. Parents are an integral part of the school's safety planning and policymaking. Life is of reasonable contentment fairly smooth career path, good health and enjoyable life-style.
# What could happen to a paper if you leave it outside even if it does not move?Good questions ask who, what, when, where, why, and how. Some reviews take even longer, compared to an average of six to eight months in Europe. Sites are accessible either by country or by subject .This service maintained by Asia Online .
# Talking to someone is pointless if they're doing what?Candidates usually run as independents. Some movement results from contraction. Assistance is available in locating living arrangements in the community.
# South America is in winter when North America is in summer, this is because it is located where?Many children have both speech and language problems while others have only speech problems. Representatives are generally from environmental staff or management, but anyone is free to join. Some reviews take even longer, compared to an average of six to eight months in Europe.
# What is someone with courage in a surprising situation not likely to feel?Site provides an author biography, and introduction to the novel. B shows the posttreatment reactions. Music sets the psychological expectation that something mammoth is about to happen.
# What is the opposite of to dignify someone?Machines prototype parts in accordance with prints and schedules. Quality control is performed by the coordinator following instructions provided by data partners. Thesis is original and goes beyond lecture and readings.
# What could stop someone from staying healthy?Property consists of multiple bldgs. Storage space is provided for forty alerts. Some effects are produced by atomic bombs.
# what does skin cover?Most companies have equipment. Events can end early. Life is hard there.
# What is a good way for children to learn about dining etiquette?Children learn through videos and activities that teach basic Christian values and principles. Birds move back and forth in route to feeding and roosting sites. Many children have both speech and language problems while others have only speech problems.
# She was playing violin with the hope of recording it someday, what did she want to do with her talent?Students discover how scientists use physical structure to sort and classify animals. Car Talk revisits some of the more interesting callers from past shows. Academic standing is reviewed at the end of each spring semester.
# What class activity is unlikely to cause boredom?Any information regarding properties for sale is confidential. Glasses reduce the focusing effort and can straighten the eyes. Education is our best defense against such needless death.
# The country enjoyed a period of peace, it was brought about by a very what time?Some homeowners actively try to soften their water using a number of different systems. Some reviews take even longer, compared to an average of six to eight months in Europe. Sites are accessible either by country or by subject .This service maintained by Asia Online .
# Billy is grooming himself in his bedroom because he wanted to be handsome for the dance.  He can't find his comb. He rushes to the store to do what with a comb?Physical oceanographers have the most enviable position of all marine scientists. Talks are underway with Germany, France and the U.S. as well. Stories are memorable because they have a beginning, middle and an end.
# What would you most likely use a blower to remove snow from?Some applications make multiple passes over the application data before determining a final result. Extreme examples are annual crops and their weeds and desert shrubs. Nobody knows what causes focal sclerosis, or kidney disease in general.
# The cows were lost in the city and hated the noise, what did they long for?Midwives provide care in both the hospital and home setting. Some interns even get to take a product all the way through the shipping phase. Some watersheds are small, and some are very large.
# Where did the two friends party and get drunk before going back to their sorority?Detection is made more difficult by the fact that the Byzantine behavior can be transient. Wild leeks are a very hearty species though, and they still thrive all over Vermont. Smokers are at much greater risk from radon in air than nonsmokers.
# If a person saw wings on a helmet, where would they be?Radiation can cause the skin near the implant to contract, leading to a poor looking result. Music sets the psychological expectation that something mammoth is about to happen. Education is our best defense against such needless death.
# What kind of place is an excavation site?Control normally returns to the command interpreter. Smiths have (part) necks. Gold is used only in modern jewelry design.
# Where is a basement likely to be small?People learn by comparing and sharing their ideas. Users can even password protect directories. Every piece is shiny and like-new.
# What does a birthday do to someone?Truth is an exercise of power. Difference is the meat of election politics. All spaces are convenient to access routes.
# Alcohol wasn't allowed at the meeting, so where did the alcoholic put his flask?Females are dull in colour, but males are brilliantly hued with iridescent plumage. All hotel rooms have private bathroom facilities and are based on single or double occupancy. Wars lead to destroyed or stolen crops and livestock and loss of vital workforce, just for starters.
# When picking an object for a baby something soft is the what option?Many magazines buy shots of their basic subject matter year-round. Bioremediation is effective in cleaning up highly polluted soils. Many seniors pick specialties where they hope to be employed after graduation.
# The business man had a big meeting that day, but his small child had gotten marker all over his fancy leather what?Birds are abundant, and make up the bulk of the endemic and native vertebrate species. Artwork changes monthly in the center, which hosts a cornucopia of artistic endeavors. Men are a three piece with a DC style that has a soulful sound mellowing it out.
# I have given up my goal of gaining more land.  Why did I give up?Radiation can cause the skin near the implant to contract, leading to a poor looking result. Some banks worry about the costs of implementing the rules. All students are encouraged to show their patriotic spirit by wearing red, white, and blue.
# The general decided to take to the only hill overlooking the field of battle that was entirely what?Regional variety is an important and strong feature of Slovenia. Ideas generated by team members then become superimposed, which enhances what can be accomplished. Residents are responsible for any damage caused by such decorations.
# Where would you get a radio if you do not have one?People are very happy to find someone they can speak with. Many people think that school sports provide enough after school activities. Short letters are FAR more likely to be read than longer ones.
# Tweed is a fabric I am looking to make clothing with, where should I go to buy some?Anarchy is a workable system, with the right kind of people. Regents attempts to operate as an extension of the family. Liquids are as likely to come out the nose as make it to the stomach.
# The installers had to move all the rows of benches, they were putting in new carpet where?Surrogates are system generated unique internal identifiers. Book emphasizes the use of various types of evidence in assessing the history of ancient Rome. International wives play a game at their first meeting each semester to learn about each other.
# When you express  this emotion you can be hurting someone else?Some fruits are too acidic until they become ripened and sweet. Teachers work closely with each other to provide continuity between each class. Some parents are so angry, that they refuse any help.
# James spent time contemplating what he had learned.  He did this to do what?Most animals have lifespans. Users give their password to other co-workers to use. Winners are usually pics that have acting noms, too.
# What is the reason for having a gardener?Glasses reduce the focusing effort and can straighten the eyes. Any information regarding properties for sale is confidential. Education is our best defense against such needless death.
# If I work in public transportation and find a door with a lock, where am I likely?Pupils spend a whole day experiencing life as a child during the wartime. Ideal candidate has strong background in the sales of routers, switches, and other data hardware. Some houses still have the beams for the hoists which lifted loads from the storage rooms.

# %%
len(sentences_merged)
# Out:
# 5000

# %%
sequences = []
answers_converted = [convert_answer_for_index(i, train_ds) for i in range(0, len(answers))]
for sentence, answer in zip(sentences_merged, answers_converted):
        sequences.append(f'{sentence} - {answer}')

# %%
len(sequences)
# Out:
# 5000

# %%
tokenized_data = tokenizer(
    sequences,
    padding='max_length',  
    return_tensors='tf',
    truncation=True,
    max_length=100 
)

# %%
len(tokenized_data['input_ids'])
# Out:
# 5000

# %%
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
input_ids = Input(shape=(100,), name='input_token', dtype='int32')
att_masks = Input(shape=(100,), name='masked_token', dtype='int32')
bert_in = bert_model(input_ids, attention_mask=att_masks)[1]
answer_output = Dense(5, activation='softmax', name='answer')(bert_in)

# %%
from tensorflow.keras.losses import mean_squared_error

# %%
model = Model(inputs=[input_ids, att_masks], outputs=[answer_output])
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(len(tokenized_data['input_ids']))
print(len(tokenized_data['attention_mask']))
print(len(answers))
# Out:
# 5000
# 5000
# 5000

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
answer_data = np.array(answers).reshape(-1, 1)
encoder = OneHotEncoder(categories=[['A', 'B', 'C', 'D', 'E']])
encoded_answer_data = encoder.fit_transform(answer_data).toarray()

# %%
encoded_answer_data.shape
# Out:
# (5000, 5)

# %%
model.fit([tokenized_data['input_ids'], tokenized_data['attention_mask']], encoded_answer_data, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 157/157 [==============================] - 2658s 17s/step - loss: 1.7483 - accuracy: 0.2038
# Epoch 2/5
# 157/157 [==============================] - 4435s 28s/step - loss: 1.6706 - accuracy: 0.1962
# Epoch 3/5
# 157/157 [==============================] - 2728s 17s/step - loss: 1.6684 - accuracy: 0.1970
# Epoch 4/5
# 157/157 [==============================] - 1512s 10s/step - loss: 1.6508 - accuracy: 0.1992
# Epoch 5/5
# 157/157 [==============================] - 1432s 9s/step - loss: 1.6592 - accuracy: 0.1980

# %%
pred_tokens = tokenizer(val_ds['question'], max_length=100, return_tensors='np', truncation=True, pad_to_max_length=True)
# Out:
# c:\Users\Mia\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:2418: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
pred_tokens['attention_mask'].shape
# Out:
# (1221, 100)

# %%
pred = model.predict([pred_tokens['input_ids'], pred_tokens['attention_mask']])
# Out:
# 39/39 [==============================] - 110s 3s/step

# %%
y_pred = []
answerKeys = ['A', 'B', 'C', 'D', 'E']

for p in pred:
    y_pred.append(answerKeys[np.argmax(p)])

# %%
y_pred
# Out:
# ['E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  ...]

# %%
y_test = val_ds['answerKey']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 accuracy = accuracy_score(y_test, y_pred)
# ----> 2 precision = precision_score(y_test, y_pred)
#       3 recall = recall_score(y_test, y_pred)
#       4 f1 = f1_score(y_test, y_pred)
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2127, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1970 @validate_params(
#    1971     {
#    1972         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1996     zero_division="warn",
#    1997 ):
#    1998     """Compute the precision.
#    1999
#    2000     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2125     array([0.5, 1. , 1. ])
#    2126     """
# -> 2127     p, _, _, _ = precision_recall_fscore_support(
#    2128         y_true,
#    2129         y_pred,
#    2130         labels=labels,
#    2131         pos_label=pos_label,
#    2132         average=average,
#    2133         warn_for=("precision",),
#    2134         sample_weight=sample_weight,
#    2135         zero_division=zero_division,
#    2136     )
#    2137     return p
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1721, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1563 """Compute precision, recall, F-measure and support for each class.
#    1564
#    1565 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1718  array([2, 2, 2]))
#    1719 """
#    1720 zero_division_value = _check_zero_division(zero_division)
# -> 1721 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1723 # Calculate tp_sum, pred_sum, true_sum ###
#    1724 samplewise = average == "samples"
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1516, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1514         if y_type == "multiclass":
#    1515             average_options.remove("samples")
# -> 1516         raise ValueError(
#    1517             "Target is %s but average='binary'. Please "
#    1518             "choose another average setting, one of %r." % (y_type, average_options)
#    1519         )
#    1520 elif pos_label not in (None, 1):
#    1521     warnings.warn(
#    1522         "Note that pos_label (set to %r) is ignored when "
#    1523         "average != 'binary' (got %r). You may use "
#    (...)
#    1526         UserWarning,
#    1527     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
