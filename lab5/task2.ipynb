# %%
from datasets import load_dataset
import torch
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from datasets import load_dataset
from transformers import BertTokenizerFast, TFBertModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import random

# %%
dataset = load_dataset("commonsense_qa")
# Out:
# Found cached dataset parquet (C:/Users/Mia/.cache/huggingface/datasets/parquet/commonsense_qa-4d2bfefd7b5e8ac5/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
generics_kb = load_dataset("generics_kb", "generics_kb")
# Out:
# Found cached dataset generics_kb (C:/Users/Mia/.cache/huggingface/datasets/generics_kb/generics_kb/1.0.0/9b41cde494db24f842a9260588bcfb2e3a257364568666ef240e98c70fb0e709)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_ds = dataset['train'][:5000]
test_ds = dataset['test']
val_ds = dataset['validation']

# %%
questions = train_ds['question']
choices = [choice['text'] for choice in train_ds['choices']]
answers = train_ds['answerKey']

# %%
kb_sentences = generics_kb['train']['generic_sentence']

# %%
# decrease the size of the knowledge base to speed up encoding
kb_sentences = random.sample(kb_sentences, 1000)

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')

# %%
len(kb_sentences)
# Out:
# 1000

# %%
max_len = 27

# %%
knowledge_base_tokens = [tokenizer.encode(sentence, return_tensors='pt')[0] for sentence in kb_sentences]

# %%
knowledge_base_tokens_padded = torch.stack([
    torch.nn.functional.pad(token, (0, max_len - len(token)))
    for token in knowledge_base_tokens
])

# %%
def convert_answer_for_index(i, ds):
    answer_index = ord(ds['answerKey'][i]) - ord('A')
    return ds['choices'][i]['text'][answer_index]

# %% [markdown]
# Tried different methods for semantic similarity, but found that cosine similarity works just as well but faster in this case. Because I am working with a smaller dataset of the knowledge base, the sentences dont have a big semantic similarity for humans. I tried:
# - spaCy's similarity method
# - cosine similarity from sentence transformers, util package

# %%
sentences_merged = []
# counter = 0
for i in range(len(questions)):
    question = questions[i]
    choices_i = choices[i]

    question_tokens = tokenizer.encode(question, return_tensors='pt')[0]
    question_tokens = torch.nn.functional.pad(question_tokens, (0, max_len - len(question_tokens)))
    # print("Question Tokens Shape:", question_tokens.shape)
    # print("Knowledge Base Tokens Shape:", knowledge_base_tokens_padded[0].shape)
    similarities = [cosine_similarity(question_tokens.detach().reshape(1, -1).numpy(), kb_token.reshape(1, -1).detach().numpy())[0][0] for kb_token in knowledge_base_tokens_padded]

    most_similar_indexes = np.argsort(similarities)[-3:]
    most_similar_indexes = [int(x) for x in most_similar_indexes]

    input_text = f"{question}"+" ".join([kb_sentences[i] for i in most_similar_indexes])
    print(input_text)

    sentences_merged.append(input_text)
    # counter += 1
    # print(counter)
# Out:
# The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?Electronic interfaces are important if the encoder is to work properly with external controls. Frequency modulation is the rate of phase modulation. Academic counselors work with students to enhance their university experience and academic success.
# Sammy wanted to go to where the people were.  Where might he go?Utmost care is taken to keep the lab and the lab equipments clean. Inflammation is a natural response of the body to any disease or damage. Progression can stop after a number of years, or can continue throughout life.
# To locate a choker not located in a jewelry box or boutique where would you go?Content includes the elements of case management process, as well as ethical and legal issues. Publishing owns and operates a complete broadcast quality digital audio and video editing studio. Risk management is embedded in nearly every facet of planning and implementing a project.
# Google Maps and other highway and street GPS services have replaced what?Representational art works Works that contain representations of real objects. Ribbon succeed beside any theatre if order sculptors. Koalas have a very slow metabolic rate, because they mostly sit in trees all day.
# The fox walked from the city into the forest, what was it looking for?Most states have a website that shows their laws on the child support subject. People begin to find that it is difficult to get open because someone is always in their way. Most keyboards come with special software that needs to be installed on the computer.
# What home entertainment equipment requires cable?Studies show certification reduces employee turnover. Numbers are limited and fees apply. Some children discover safe deposit boxes.
# The only baggage the woman checked was a drawstring bag, where was she heading with it?Regular activity reduces stress, prevents depression, and improves quality of sleep. World cup racing no longer allows low-score dropping. Appendices contain species lists for all fauna surveyed.
# The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?People worry about landfills getting too full. Calendar can have alarms sent to a cell phones or an e-mail address as chosen by the user. Women produce the bulk of food in the world, but they eat the smallest portion of it.
# What do people use to absorb extra ink from a fountain pen?Careful map reading best precedes any trip in unfamiliar areas. All models are easy to install and include all required hardware. Local competitions allow students to showcase their solutions to the challenge.
# Where is a business restaurant likely to be located?Ideas Keep a project journal of the group work. Example is far more lasting in results than entertainment. Electric energy plays a vital role in our lives.
# Where do you put your grapes just before checking out?People Meet the students, instructors, and guest speakers. All musicians are very good choices to their roles. Gold Lake is a fly fisherman's paradise.
# Before getting a divorce, what did the wife feel who was doing all the work?Schools Helping over visitors, find just what they wanted . . . Foreign residents live securely, and in pleasant surroundings, in all regions of the country. Local authorities are unwilling to challenge the companies in court due to the expense involved.
# Johnny sat on a bench and relaxed after doing a lot of work on his hobby.  Where is he?Most waves used in radar, sonar, and ultrasonic technologies, are also transient. Families are gathered under orders, or in some cases, into superfamilies under the orders. Silver Creek is a great place for families to get their first taste of Colorado skiing.
# James was cooling off two quickly.  He would die if he didn't find some way to stop what?Many women literally have no choice about whether to get someone else to take care of their kids. Style is meaningless - it is the gospel message that is important, and the walk of the musician. Unregulated industry steps all over everyone, starting with it's own employees.
# Of all the rooms in a house it was his favorite, the aromas always drew him to the what?Cardinal marks are yellow and black, and are placed according to the compass direction of a danger. Some issuers use the two-cycle average daily balance method when calculating finance charges. Researchers say the surgery can be used anywhere in the body a bone graft is needed.
# Bill is stuck in marsh when a man comes up to him peaking Cajun, where is he?Final sections review resources and costs for the various programs, and efforts at replication. Some men require additional hair in the crown, and possibly the mid-scalp as well. Good humor is a frame of mind, a healthy, wholesome, vibrant way of seeing things.
# What is it called when you slowly cook using a grill?Social casework is viewed as the process of problem solving. Gentle peaks lead into bowly sections, with a racetrack wall inside to finish it off. Local roads are the core of the state's roadway network.
# What type of person typically contracts illness?Students participate in formal art instruction weekly. All times are subject to weather conditions. Students receive four terms of honors credit.
# Where would you expect to find a pizzeria while shopping?Adaptation is a common property of many sensory receptors. GAS is required for -g and exception handling support. Human history is an excellent example of aperiodic behavior.
# When eating everything on the tasting menu, what does one tend to feel?Most images presented on the Zoom Photography site are available in digital form for commercial use. State law requires a machine recount whenever the margin is less than half a percent. Known rivals are The Junior Chickadees , a similar girls' organisation.
# What does playing soccer for a long time lead to?Schools Helping over visitors, find just what they wanted . . . Subject areas are consistent with the Collection Management Policy . Many rooms have views over the city from on high.
# Which entrance would you use if you do not want to use the back entrance?Training is designed and developed to address the needs considered most critical to the group. People begin to find that it is difficult to get open because someone is always in their way. Many programs designed to fill other needs also include basic Web-authoring tools.
# You can share files with someone if you have a connection to a what?Additional support is provided through technical support and e-mail. Many properties enjoy magnificent views of the sea and the spectacular Caribbean sunsets. Many marketers utilize in-kind gifts or product donations to support a cause.
# The accelerator was controller via a hand throttle, and the foot pedals controlled the steering in the small what?Frequency modulation is the rate of phase modulation. Academic counselors work with students to enhance their university experience and academic success. Electronic interfaces are important if the encoder is to work properly with external controls.
# Sean was lying about the body, but he was very scared.  He constantly worried about what?Filters are a powerful way to manage one's mailbox on an everyday basis. Grades are generally available on both systems about a week after the last day of finals. Some students attend part-time and of course, take longer to get their degrees.
# The drug kingpin told his man to run errands, this was code to go to all the dealers to do what they had?Many churches have cell groups, where members have optional participation. Membership is open to any student or staff with diving certification. Students also have the chance to develop their own advertising campaigns.
# Though he could've kept going his body appreciated the rest, it had been constantly what during the day?Lead paint is the number one cause of lead poisoning in children. Nobody can describe it perfectly, but they immediately recognise it when they see it. Units vary in size from one bedroom units with lofts to three bedroom units.
# Too many people want exotic snakes.  The demand is driving what to carry them?Approved models have two elastic straps in back for a better seal. Most fruit trees require pruning to control branch spread as well as tree height. Sales are strong, customer satisfaction is rising, and costs are being contained.
# Joe suffered many consequences from stabbing a stranger to death.   Among them, the family of the victim did something to him. What was that?People have their dreams and desires. Subject matter includes politics, battles, and life in the U.S. during the war. Community needs better supports - ratios, and more money to provide better supports.
# To prevent any glare during the big football game he made sure to clean the dust of his what?Women produce the bulk of food in the world, but they eat the smallest portion of it. Local authorities are unwilling to challenge the companies in court due to the expense involved. Class promotes self awarness, self discipline, physical fitness, self-confidence, and lots of fun.
# I have something in my head I want to share, what ways can I do that?Life is the first gift, love is the second, and understanding is the third. People look at a picture the same way they read - left to right, top to bottom. People begin to find that it is difficult to get open because someone is always in their way.
# He wanted a house that was gated off from other places, where should he start looking?Training is designed and developed to address the needs considered most critical to the group. People look at a picture the same way they read - left to right, top to bottom. People begin to find that it is difficult to get open because someone is always in their way.
# Where in Southern Europe would you find many canals?Emphasis is on having fun while learning to manipulate art materials. Every dive cruise offers two to three daily immersions. Many functions return a value, even the simplest ones.
# What would a camper need to do before he or she can start cooking food?Final sections review resources and costs for the various programs, and efforts at replication. Women produce the bulk of food in the world, but they eat the smallest portion of it. Students have use of the kitchen facilities and are responsible for providing their own meals.
# What could happen to a paper if you leave it outside even if it does not move?Some students attend part-time and of course, take longer to get their degrees. People begin to find that it is difficult to get open because someone is always in their way. Many women literally have no choice about whether to get someone else to take care of their kids.
# Mark's semen was very thick, but after his vasectomy it was also what?Felonies are serious crimes such as murder, rape, arson, theft of highly valued property. Content includes the elements of case management process, as well as ethical and legal issues. Good humor is a frame of mind, a healthy, wholesome, vibrant way of seeing things.
# What is a great place to lay in the sun?Technology can make large-scale collaboration and information sharing possible. Students use their library cards to check out reserve items. Force is the only way to keep people in line.
# Where would you find a seafood restaurant in the east coast of North America?Some churches have classes for preschoolers during the worship service. Wine glass is located in cupboards. Most images presented on the Zoom Photography site are available in digital form for commercial use.
# The president is the leader of what institution?Associated companies make a wide variety of instruments. Information is an important element of policy decisions. Music is to be primarily used for worship.
# Sitting to close while watching TV can cause what sort of pain?Force is the only way to keep people in line. Fit people are also eight times less likely to die from heart disease. Counties can lead the effort to move people from welfare to work.
# Where is a bald eagle safe?All students receive technological instruction. Some domestic dogs transmit diseases. Communication is the crux of the issue.
# The game promised it was free, but the child's parents soon found themselves doing what for microtransactions?Koalas are also marsupials, meaning that it carries it's young in a pouch found on the belly. Rooms come with a safe and mini-bar, blow dryer and a huge glass tank of purified water. Wheat berry is a crunchy grain that can be served either hot as a side dish, or cold as a cereal.
# What kind of driving leads to accidents?Younger people look to it for inspiration. Every game here is like a playoff game. Food consists mainly of rice and noodles.
# What is eating too much dinner likely to result in?Many government agencies have branch offices throughout the country and throughout the world. Current law requires only a vote by the county commission. Council members participate in the important programs described below.
# What is a person chatting with friends likely hoping to accomplish?Fish also like to linger around natural structures such as weeds, fallen tree, and drop-offs. Computer desks have ample room for student media, notebooks and class manuals. Colors are a mind bender, so just take the info for what it is.
# Jame's bare feet were burned as he walked, because the sunshine had made the surface hot.  Where might he have been?Sizes vary in length depending on the baby's name and the design chosen. Portfolios present an artist's work, professionalism, history and overall style. Leaps are long-term options, CAPs are index options that resemble vertical spreads.
# A fox was thirsty searching for water during the drought, where was he?People worry about landfills getting too full. Weight watchers pronunciation Course stored during several weight watchers. Liberty City is multicultural, youth oriented, and urbane.
# What might be the result of a season of successful skiing?Gentle peaks lead into bowly sections, with a racetrack wall inside to finish it off. Social casework is viewed as the process of problem solving. Local roads are the core of the state's roadway network.
# The sensor would just the distance then set off an alarm, the installation expert explained it was called a what kind of sensor?Barbets can be small to medium sized and are similar to woodpeckers. Most keyboards come with special software that needs to be installed on the computer. Lowercase terms match any case, otherwise case is matched exactly as typed.
# The man was eating lunch, but rushed when he looked at his watch, why did he rush?Most people only get to go to Hawaii once in their life, if at all. People begin to find that it is difficult to get open because someone is always in their way. Most people use the word ghost to refer to something that is seen but has no material existance.
# The evacuation became mandatory, so what came on the TV?Most diets consist of natural food. Some guanacos develop skin. Past indiscretions are history and of no importance.
# The person gave a good hands on what to show how to do the work?People begin to find that it is difficult to get open because someone is always in their way. Most states have a website that shows their laws on the child support subject. Training is designed and developed to address the needs considered most critical to the group.
# Where would you see some people doing jumping jacks?Entries are brief but include cross referential links. Representational art works Works that contain representations of real objects. Lake County is a single-county waste district.
# The body guard was good at his duties, he made the person who hired him what?Most people only get to go to Hawaii once in their life, if at all. People begin to find that it is difficult to get open because someone is always in their way. Students can change the information on their assignment information form as often as they wish.
# Learning languages is difficult.  Even in a full immersion environment you're likely to make mistakes, mistakes will cause misinterpretation, which will be uncomfortable, which will cause what?,Lead paint is the number one cause of lead poisoning in children. Orders is a sample order entry and invoicing system. Test sites being explored include finger tips, cuticle, finger web, forearm and ear lobe.
# Jim enjoyed killing people, but he did it too often and the cops found out.  What might the cops do to him?Marines engaging zerglings look like blue and gray blobs bumping into red and purple blobs. Some clubs meet in leader's or member's homes or garages. Cardinal marks are yellow and black, and are placed according to the compass direction of a danger.
# Where is there usually a fiddle playing?Some people can benefit from scalp reduction. Most flowers produce sugary nectar. Wine glass is located in cupboards.
# What is the only was to recover from exhaustion?Modern systems can also operate automatic gates and regulate flow. Gold speaks at off-campus conferences, gatherings, and community events. Many men step out of a monogomous marriage in the quest for money and power.
# What would you do if you want to be able to earn money?Full support is provided by the blood bank, laboratory and affiliated departments. Blackboard is a web-based tool to deliver online instructional resources. Most companies lack the personnel and technology infrastructure to gather and analyze the data.
# What is a grumpy person likely to have?All students receive technological instruction. Extensive glaciation persists in what is now India, Australia, and Antarctica. Hair has other symbolic meanings as well.
# What do drugs do?Music is excellent. Money is backed by law. Some sports involve water.
# A beaver can destroy a machines functionality if they build their dam in this?ALL donations go towards helping the pets in our foster program. Independent travelers are welcome, inquire. Solar flares create a massive electromagnetic explosion in the upper solar atmosphere.
# They decided to hash things out over drinks, after enough booze they were able to get close on a few things and what?Speech recognition is handled by a standard package to create an input text string. Any help is welcome, as are comments, but no arguments, about correct order. Patients receive physician consultation, necessary lab tests, and all medications free of charge.
# Where could a fungus grow and not be disturbed by sunlight?Calendar can have alarms sent to a cell phones or an e-mail address as chosen by the user. Petitioners also contend that many of the allegations in the letter are false. Foreign residents live securely, and in pleasant surroundings, in all regions of the country.
# Can you name a good reason for attending school?Associated companies make a wide variety of instruments. Music is to be primarily used for worship. Lake County is a single-county waste district.
# What state south of Kentucky and north of Alabama will you find people playing the fiddle?Nothing is done if the string value is of zero length or sender is nil. Families are gathered under orders, or in some cases, into superfamilies under the orders. Silver Creek is a great place for families to get their first taste of Colorado skiing.
# Though she made the cut years ago, its figurative scars would never what?Service is deft, knowledgeable and always gracious. Many churches have cell groups, where members have optional participation. Many schools require the test as part of the admissions procedure.
# What does sex often make happen in people?Business seems to be doing quite well. Bad things come in more than threes. Members pay dues to support the site.
# Where would you see people in uniform playing with a ball?Some people believe that the game dates back a lot further than that. Water is from an underground aquifer and rainwater. Love is a special, secret joke held between two people.
# What kind of place could have a seafood restaurant?Ribbon succeed beside any theatre if order sculptors. All sections take the midterm quiz during class session Five. Respect is a key factor in our dealings with people.
# Who was the head of the branch yelling at?All sections take the midterm quiz during class session Five. Entries are brief but include cross referential links. Respect is a key factor in our dealings with people.
# He made another call, he did this all day hoping people would what well to his offer?People look at a picture the same way they read - left to right, top to bottom. Many women literally have no choice about whether to get someone else to take care of their kids. People begin to find that it is difficult to get open because someone is always in their way.
# She needs to visit a bookshop after buying the latest fashion, where should she look?Students are able to win a monthly prize drawing by entering for each book they read. Work is untimely, inaccurate and incomplete. Love is a special, secret joke held between two people.
# Where could you see an advertisement while reading news?Nuclear energy is just one subset. Some churches have classes for preschoolers during the worship service. Wine glass is located in cupboards.
# What is required to be good at playing tennis?GAS is required for -g and exception handling support. Consumer services guide Concerts coming up hereabouts. Offers support specifically to individuals from the church constituency.
# What state is the John Davis  Lodge toll road found in?Representational art works Works that contain representations of real objects. Summer rain comes mainly as brief thunderstorms in the middle and late afternoon. Judges gain points by participating in judging contests as active judges.
# The man went to clown college, he had always want to run away with the what?Poor marketing can endanger the success of the business. Voles are primarily vegetarian, which means they eat plants, flowers and other greenery. Temperatures remain within a narrower band than is the case in many other parts of the Kingdom.
# WHat do cats get into when they are ripping things apart?Simple operation saves money by saving time while delivering quality patient care. Many functions return a value, even the simplest ones. Every dive cruise offers two to three daily immersions.
# What is a good result of losing weight?Food courts are areas where people buy food . Technology occurs in a non-magical context. Information is an important element of policy decisions.
# A person lived in my what?More file operations show progress now. Many foreign titles are available. More digital effects are available.
# The skin was cut while chopping onions, where was this skin likely cut?Summer rain comes mainly as brief thunderstorms in the middle and late afternoon. Most men feel lonely, isolated and disconnected. Local competitions allow students to showcase their solutions to the challenge.
# What might you feel after doing housework for hours?All items are from a non-smoking environment. Music is to be primarily used for worship. Lake County is a single-county waste district.
# The accountant used a calculator regularly, he kept one at home and one at the what?Foreign seminars have a different tuition schedule. Gas hydrate is a crystalline solid formed of water and gas. Most rodents look like fat squirrels.
# At the end of your meal what will a waiter do?Many schools require the test as part of the admissions procedure. Orders is a sample order entry and invoicing system. Regular activity reduces stress, prevents depression, and improves quality of sleep.
# If you aren't glad, unhappy or gloomy, what illness may you have?Units vary in size from one bedroom units with lofts to three bedroom units. Associations also establish objective standards to guide buyers in evaluating products. Nothing is sacred in the hands of marijuana-addicted producers.
# You can hear testimony of how spirituality changes lives when you do what?Daily study is preferable to intermittent cramming. Great care is devoted to all phases of processing. Initial training covers orientation and training assignments in contract administration.
# It was a great rest, she had never felt this much what in the morning?Members can make free web site promotion and free advertising at lowest rate on the Internet. Life is the first gift, love is the second, and understanding is the third. People begin to find that it is difficult to get open because someone is always in their way.
# Which region has the most famous temple?Students read the history of the island. Legal help is necessary for estate planning. All times are subject to weather conditions.
# Where would you find a bee gathering pollen?Respect is a key factor in our dealings with people. Summer rain comes mainly as brief thunderstorms in the middle and late afternoon. Most men feel lonely, isolated and disconnected.
# Where would you put a folding chair if you do not plan to use it and you do not have any large doors in your house?Subject matter includes politics, battles, and life in the U.S. during the war. Community needs better supports - ratios, and more money to provide better supports. Most images presented on the Zoom Photography site are available in digital form for commercial use.
# If you're speaking to a lawyer about getting a divorce, what relationship status are you trying to end?Most companies lack the personnel and technology infrastructure to gather and analyze the data. Every action is a reaction to another action, which was spawned by another event before it. Any help is welcome, as are comments, but no arguments, about correct order.
# How do geese normally get from place to place?Most barometric pressure indicates weather. Most anemones have different grow requirements. Some government buys cattle.
# John was punching and punching at the wall but succeeded only in bloodying his knuckles. This was bad.  He would be unable to hold his tools if he injured what?Vocals are incredibly lifelike. Pronghorns mate each fall in the dry, open lands of western North America. Playing field update Some fencing and a new gate had still to be put up.
# Though it stayed strictly indoors, the small dog felt like it had all the space in the world in the what?Extensive glaciation persists in what is now India, Australia, and Antarctica. Attendance is required unless excused absence by faculty member. Most dogs require sufficient nutrients.
# WHat leads to someone's death when they are very depressed?Camping is available in most park units and local communities provide lodging. Every action is a reaction to another action, which was spawned by another event before it. Blackboard is a web-based tool to deliver online instructional resources.
# She was sick and staying in bed the day of the event, unfortunately this meant she was what?Some clubs meet in leader's or member's homes or garages. People look at a picture the same way they read - left to right, top to bottom. Systems are methods of doing something, a way of carrying out a task or operation.
# Where would a lizard surprise a person?Communication is the crux of the issue. People worry about landfills getting too full. Tables list the alarms associated with objects.
# They were getting together for the big game, he wasn't hosting but made sure to bring pretty of food with him over to where?Researchers say the surgery can be used anywhere in the body a bone graft is needed. Some issuers use the two-cycle average daily balance method when calculating finance charges. Cardinal marks are yellow and black, and are placed according to the compass direction of a danger.
# Who is likely yo have a caring heart?Some people have beers in a pub. Books make great gifts for any occasion. Initial training covers orientation and training assignments in contract administration.
# I'm looking for alcohol and fried foods, any suggestions?Theme comes with icons, animated cursors, wallpaper and specially designed Santa sounds. . Visitors can enjoy camping and picnics on Mt. Lemmon throughout most of the year. Featured areas are Canada, Palestine, Kenya, China and Cambodia.
# If I had a jar which was likely to spoil if left out, where would I want to put it?Open fields provide feeding habitats for small mammals and migratory birds. Nobody can describe it perfectly, but they immediately recognise it when they see it. Cooperation is the watchword, and the film illustrates that it works.
# Sam went to Paris where he ordered a blowfish at a sushi place.  Where was Sam?Dead nits remain attached to the hair shaft until they are combed out or the hair falls out. Inmates walk alone or in pairs along the concrete pathways, offering greetings as they pass. Auto racing is about more than crashing, rubbing fenders and plugging sponsors.
# What will happen to skin pinched in something?Nuclear energy is just one subset. Most flowers produce sugary nectar. Wine glass is located in cupboards.
# Sally lost her kite because she wasn't careful.  She thought that there was more string on the spool, but it slipped out of her fingers when she reached the what?.Fees are very predictable. Calendar can have alarms sent to a cell phones or an e-mail address as chosen by the user. Liberty City is multicultural, youth oriented, and urbane.
# The man uses grooming before a job interview, what is he trying to portray?Foreign residents live securely, and in pleasant surroundings, in all regions of the country. Venzuni soils are on alluvial fans on valley sides and stream terraces on valley floors. Contributions are deductible for U.S. citizens and residents as charitable contributions.
# Where would there be many people sitting in chair and listening to religious speech?Students are able to win a monthly prize drawing by entering for each book they read. Service is offered in English, French, German, Italian and Spanish. Most states have a website that shows their laws on the child support subject.
# Where is a tabby cat likely to be happiest?Many marketers utilize in-kind gifts or product donations to support a cause. Liberty City is multicultural, youth oriented, and urbane. Weight watchers pronunciation Course stored during several weight watchers.
# East coast areas such as Florida are found where?Communications provide the basis for sharing information or equipment. Bad things come in more than threes. Members pay dues to support the site.
# To learn must have the right book, to work efficiently what must one have?Social casework is viewed as the process of problem solving. Gentle peaks lead into bowly sections, with a racetrack wall inside to finish it off. Local roads are the core of the state's roadway network.
# What is a mobile launching platform found in the ocean?Attendance is required unless excused absence by faculty member. Travel is about human interaction, hands-on experience. Men continue to outnumber women at the doctoral level.
# There weren't potatoes but actually a snake in his what?Families can win additional prizes and goodie bags. Example is far more lasting in results than entertainment. Introduction refers to the introductory material in the printed work.
# What could listening to music cause you to be?Students can click the subject heading to link directly to that page. Current law requires only a vote by the county commission. Council members participate in the important programs described below.
# If you want to make a big splash in a river with a rock, from where should you throw it?All sections take the midterm quiz during class session Five. Respect is a key factor in our dealings with people. Forms of life are arranged in groups subordinate to groups, all in a few great classes.
# What is committing perjury likely to lead to?China now enjoys a higher international status in the world. Evidence also demonstrates a genetic connection. All alums are welcome to participate in any committee meeting or event.
# The new play was the go to performance of the year, all the crowds would stand and what?Students have use of the kitchen facilities and are responsible for providing their own meals. Final sections review resources and costs for the various programs, and efforts at replication. Some men require additional hair in the crown, and possibly the mid-scalp as well.
# "There are 10 apples on an apple tree.  Three fall off.  Now there are X apples."  What is this an example of?Most people use the word ghost to refer to something that is seen but has no material existance. Frameworks require close adherence to their proprietary standards across systems. Fish also like to linger around natural structures such as weeds, fallen tree, and drop-offs.
# Where are people likely to find food?Training can even improve the bottom line. Any state can occur more than once. Legal help is necessary for estate planning.
# What might a kid do with his friend before going to play?Physical education is taught throughout elementary, middle and high school. Many rooms have views over the city from on high. Schools Helping over visitors, find just what they wanted . . .
# What is a person who is well educated?Associated companies make a wide variety of instruments. Information is an important element of policy decisions. Music is to be primarily used for worship.
# Ben was an alcoholic and was in an accident.  Because of his mistake, he spent 8 years somewhere. Where was he?Local authorities are unwilling to challenge the companies in court due to the expense involved. Petitioners also contend that many of the allegations in the letter are false. Calendar can have alarms sent to a cell phones or an e-mail address as chosen by the user.
# Where do you buy tickets at a ticket booth for games/Example is far more lasting in results than entertainment. Customers also receive automatic confirmation when their calls enter the system. Families can win additional prizes and goodie bags.
# A soccer field that is not contained in a building would be where?Solar flares create a massive electromagnetic explosion in the upper solar atmosphere. Final payment is due upon the completion of the scheduled event. Some people believe that the game dates back a lot further than that.
# Letters are sometimes delivered by hand through one of these.Force is the only way to keep people in line. Many rooms have views over the city from on high. Subject areas are consistent with the Collection Management Policy .
# John came to see Sam and Sam kicked him out.  Sam didn't like company.  He prefered what?Elevated temperature can pasteurize or sterilize softwood chips, sawn wood, or logs. Keen observation is the key to culling the false anomalies from the seepage anomalies. Koalas are also marsupials, meaning that it carries it's young in a pouch found on the belly.
# If somebody likes temperatures cool, they might have more than one electric fan where?Many banks maintain trust departments which can be selected to manage the trust estate. Marines engaging zerglings look like blue and gray blobs bumping into red and purple blobs. All volunteers receive specialized training and are certified by federal and state revenue agencies.
# Sky diving scared him, once they jumped out of the plane he began losing consciousness while what?Barbets can be small to medium sized and are similar to woodpeckers. People begin to find that it is difficult to get open because someone is always in their way. Some students attend part-time and of course, take longer to get their degrees.
# The president had to make a decision regarding the hate attack on his country, what did he do?Most people only get to go to Hawaii once in their life, if at all. People look at a picture the same way they read - left to right, top to bottom. People begin to find that it is difficult to get open because someone is always in their way.
# What's it called when you have seen something through an eyepiece?Some issuers use the two-cycle average daily balance method when calculating finance charges. Participants are responsible for travel to and from Mexico City and incidental expenses. Researchers say the surgery can be used anywhere in the body a bone graft is needed.
# He had done a great job with the scary decorations, they were completely what?Fishing is done once a year as a collective venture. Students participate in the care of patients under physician supervision. Great care is taken in making up the bunk groupings.
# If you did well on the test, you might get an A as a what?Some people believe that the game dates back a lot further than that. Students are able to win a monthly prize drawing by entering for each book they read. Training is designed and developed to address the needs considered most critical to the group.
# If you tell you boss your suffering from boredom they'll likely tell you to get back to what?Emphasis is on having fun while learning to manipulate art materials. Gold speaks at off-campus conferences, gatherings, and community events. Many functions return a value, even the simplest ones.
# What is a good result of jogging?Film making is the art of storytelling with pictures. Food consists mainly of rice and noodles. Incest is a class E felony.
# What is done to wood to attach something to it?Incest is a class E felony. Food consists mainly of rice and noodles. Film making is the art of storytelling with pictures.
# Where is a fox likely to be caught?Any state can occur more than once. True vision is granted only to the few. Most experts prefer iodine over chlorine.
# ...
# Where is bacteria likely to be found naturally?Land always descends to the next of kin at the moment of death. Lines are horizontal lines that form trading ranges. Good schools sustain property values for homeowners.
# The horse was decorated because it was taking part in something. What was it in?Local authorities are unwilling to challenge the companies in court due to the expense involved. Many rooms have views over the city from on high. Schools Helping over visitors, find just what they wanted . . .
# What does a long session of procreating cause?All sections take the midterm quiz during class session Five. Lake County is a single-county waste district. Respect is a key factor in our dealings with people.
# Where would you put scissors if you will need to use them in another building soon?Temperatures remain within a narrower band than is the case in many other parts of the Kingdom. Mission is on our doorstep. Poor marketing can endanger the success of the business.
# The signs went from English to French, they had traveled far along the national highway where?Systems are methods of doing something, a way of carrying out a task or operation. Most keyboards come with special software that needs to be installed on the computer. People begin to find that it is difficult to get open because someone is always in their way.
# After a while playing, what was happening to the children?Most people only get to go to Hawaii once in their life, if at all. Membership provides many benefits , including our roster, published annually. Representational art works Works that contain representations of real objects.
# WHat do you use to recording something?Business seems to be doing quite well. Legal help is necessary for estate planning. All times are subject to weather conditions.
# The sloth was very muscular, but he couldn't compete in the contest because it had a humans only rule.  What contest was the sloth trying to enter?Most rodents look like fat squirrels. Gas hydrate is a crystalline solid formed of water and gas. Computer algorithms exist that can convert data of one type to the other.
# What do you put around a garden to keep animals out?Technology can make large-scale collaboration and information sharing possible. Force is the only way to keep people in line. Students use their library cards to check out reserve items.
# HOw do you watch film before its on video?Many rooms have views over the city from on high. Subject areas are consistent with the Collection Management Policy . Force is the only way to keep people in line.
# If you're relaxing with friends and you agree with one but not the other, what have you done?Men continue to outnumber women at the doctoral level. Poor marketing can endanger the success of the business. Temperatures remain within a narrower band than is the case in many other parts of the Kingdom.
# When we judge people what do we tend to do to them?Lake County is a single-county waste district. Genetic engineering has the potential to revolutionalize medicine and agriculture. Most people only get to go to Hawaii once in their life, if at all.
# Sammy wanted to preserve the wallpaper, but it was wet and had already begun to do what?Younger people look to it for inspiration. Salads have eight or nine greens. Cedar has (part) treetops.
# The largest train stations are in what areas?Bad things come in more than threes. True vision is granted only to the few. Members pay dues to support the site.
# She was worried about driving car, she was worried what might flare up during a long drive?Dead nits remain attached to the hair shaft until they are combed out or the hair falls out. Content includes the elements of case management process, as well as ethical and legal issues. Length length takes one argument, a list, and returns an integer giving the length of the list.
# Where would you get nails if you do not have any?Example is far more lasting in results than entertainment. Introduction refers to the introductory material in the printed work. Travel is about human interaction, hands-on experience.
# To where do apple trees drop their fruit?Information is an important element of policy decisions. Music is to be primarily used for worship. Individual plants have adaptations to ensure their survival through a fire.
# A saltshaker is often used with what container for lipids?Studies analyze institutional processes and results to find ways to improve both. Most folks search for and find sites and individual pages from the Web . Perceptive gardeners consider the plant's age when it is attacked.
# John stood in the courtyard and watched the bulls.  Where might he have been?Community See how students across the country are voting on the issues. Homes range from studio flats to generously proportioned five bedroom houses. Families can win additional prizes and goodie bags.
# What is likely to be filled with noxious water?Emphasis is on having fun while learning to manipulate art materials. Every dive cruise offers two to three daily immersions. Many functions return a value, even the simplest ones.
# Where would you put a tote bag while you are getting some food?Students can change the information on their assignment information form as often as they wish. Speech recognition is handled by a standard package to create an input text string. Most people only get to go to Hawaii once in their life, if at all.
# James spent time contemplating what he had learned.  He did this to do what?Tables list the alarms associated with objects. Blue eyes are disqualifications. People worry about landfills getting too full.
# What is the reason for having a gardener?Ribbon succeed beside any theatre if order sculptors. Most men feel lonely, isolated and disconnected. Respect is a key factor in our dealings with people.
# If I work in public transportation and find a door with a lock, where am I likely?Felonies are serious crimes such as murder, rape, arson, theft of highly valued property. Students think about it alone for five minutes or less, then pair up to discuss their views. DRAW reaches out to every drag racing category and all racing sanctioning bodies.

# %%
len(sentences_merged)
# Out:
# 5000

# %%
sequences = []
answers_converted = [convert_answer_for_index(i, train_ds) for i in range(0, len(answers))]
for sentence, answer in zip(sentences_merged, answers_converted):
        sequences.append(f'{sentence} - {answer}')

# %%
len(sequences)
# Out:
# 5000

# %%
tokenized_data = tokenizer(
    sequences,
    padding='max_length',  
    return_tensors='tf',
    truncation=True,
    max_length=100 
)

# %%
len(tokenized_data['input_ids'])
# Out:
# 5000

# %%
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
input_ids = Input(shape=(100,), name='input_token', dtype='int32')
att_masks = Input(shape=(100,), name='masked_token', dtype='int32')
bert_in = bert_model(input_ids, attention_mask=att_masks)[1]
answer_output = Dense(5, activation='softmax', name='answer')(bert_in)

# %%
from tensorflow.keras.losses import mean_squared_error

# %%
model = Model(inputs=[input_ids, att_masks], outputs=[answer_output])
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(len(tokenized_data['input_ids']))
print(len(tokenized_data['attention_mask']))
print(len(answers))
# Out:
# 5000
# 5000
# 5000

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
answer_data = np.array(answers).reshape(-1, 1)
encoder = OneHotEncoder(categories=[['A', 'B', 'C', 'D', 'E']])
encoded_answer_data = encoder.fit_transform(answer_data).toarray()

# %%
encoded_answer_data.shape
# Out:
# (5000, 5)

# %%
model.fit([tokenized_data['input_ids'], tokenized_data['attention_mask']], encoded_answer_data, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 152/157 [============================>.] - ETA: 55s - loss: 1.7020 - accuracy: 0.1916

# %%
pred_tokens = tokenizer(val_ds['question'], max_length=100, return_tensors='np', truncation=True, pad_to_max_length=True)

# %%
pred_tokens['attention_mask'].shape
# Out:
# (1221, 100)

# %%
pred = model.predict([pred_tokens['input_ids'], pred_tokens['attention_mask']])
# Out:
# 17/39 [============>.................] - ETA: 1:19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 pred = model.predict([pred_tokens['input_ids'], pred_tokens['attention_mask']])
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\keras\src\engine\training.py:2631, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2629 for step in data_handler.steps():
#    2630     callbacks.on_predict_batch_begin(step)
# -> 2631     tmp_batch_outputs = self.predict_function(iterator)
#    2632     if data_handler.should_sync:
#    2633         context.async_wait()
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:876, in Function._call(self, *args, **kwds)
#     873 self._lock.release()
#     874 # In this case we have not created variables on the first call. So we can
#     875 # run the first trace but we should fail if variables are created.
# --> 876 results = tracing_compilation.call_function(
#     877     args, kwds, self._variable_creation_config
#     878 )
#     879 if self._created_variables:
#     880   raise ValueError("Creating variables on a non-first call to a function"
#     881                    " decorated with tf.function.")
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1264, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1260 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1261 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1262     and executing_eagerly):
#    1263   # No tape is watching; skip to running the function.
# -> 1264   return self._inference_function.flat_call(args)
#    1265 forward_backward = self._select_forward_and_backward_functions(
#    1266     args,
#    1267     possible_gradient_type,
#    1268     executing_eagerly)
#    1269 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:217, in AtomicFunction.flat_call(self, args)
#     215 def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216   """Calls with tensor inputs and returns the structured output."""
# --> 217   flat_outputs = self(*args)
#     218   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:252, in AtomicFunction.__call__(self, *args)
#     250 with record.stop_recording():
#     251   if self._bound_context.executing_eagerly():
# --> 252     outputs = self._bound_context.call_function(
#     253         self.name,
#     254         list(args),
#     255         len(self.function_type.flat_outputs),
#     256     )
#     257   else:
#     258     outputs = make_call_op_in_graph(
#     259         self,
#     260         list(args),
#     261         self._bound_context.function_call_options.as_attrs(),
#     262     )
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1479, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1477 cancellation_context = cancellation.context()
#    1478 if cancellation_context is None:
# -> 1479   outputs = execute.execute(
#    1480       name.decode("utf-8"),
#    1481       num_outputs=num_outputs,
#    1482       inputs=tensor_inputs,
#    1483       attrs=attrs,
#    1484       ctx=self,
#    1485   )
#    1486 else:
#    1487   outputs = execute.execute_with_cancellation(
#    1488       name.decode("utf-8"),
#    1489       num_outputs=num_outputs,
#    (...)
#    1493       cancellation_manager=cancellation_context,
#    1494   )
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# KeyboardInterrupt:

# %%
y_pred = []
answerKeys = ['A', 'B', 'C', 'D', 'E']

for p in pred:
    y_pred.append(answerKeys[np.argmax(p)])

# %%
y_pred
# Out:
# ['B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  ...]

# %%
y_test = val_ds['answerKey']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 2
#       1 accuracy = accuracy_score(y_test, y_pred)
# ----> 2 precision = precision_score(y_test, y_pred)
#       3 recall = recall_score(y_test, y_pred)
#       4 f1 = f1_score(y_test, y_pred)
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2127, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1970 @validate_params(
#    1971     {
#    1972         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1996     zero_division="warn",
#    1997 ):
#    1998     """Compute the precision.
#    1999
#    2000     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2125     array([0.5, 1. , 1. ])
#    2126     """
# -> 2127     p, _, _, _ = precision_recall_fscore_support(
#    2128         y_true,
#    2129         y_pred,
#    2130         labels=labels,
#    2131         pos_label=pos_label,
#    2132         average=average,
#    2133         warn_for=("precision",),
#    2134         sample_weight=sample_weight,
#    2135         zero_division=zero_division,
#    2136     )
#    2137     return p
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1721, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1563 """Compute precision, recall, F-measure and support for each class.
#    1564
#    1565 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1718  array([2, 2, 2]))
#    1719 """
#    1720 zero_division_value = _check_zero_division(zero_division)
# -> 1721 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1723 # Calculate tp_sum, pred_sum, true_sum ###
#    1724 samplewise = average == "samples"
#
# File c:\Users\Mia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1516, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1514         if y_type == "multiclass":
#    1515             average_options.remove("samples")
# -> 1516         raise ValueError(
#    1517             "Target is %s but average='binary'. Please "
#    1518             "choose another average setting, one of %r." % (y_type, average_options)
#    1519         )
#    1520 elif pos_label not in (None, 1):
#    1521     warnings.warn(
#    1522         "Note that pos_label (set to %r) is ignored when "
#    1523         "average != 'binary' (got %r). You may use "
#    (...)
#    1526         UserWarning,
#    1527     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
y_pred
# Out:
# ['D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  ...]

# %%
y_test
# Out:
# ['A',
#  'A',
#  'B',
#  'A',
#  'A',
#  'C',
#  'B',
#  'D',
#  'A',
#  'C',
#  'E',
#  'D',
#  'A',
#  'D',
#  'C',
#  'D',
#  'D',
#  'E',
#  'E',
#  'D',
#  'D',
#  'C',
#  'D',
#  'D',
#  'E',
#  'D',
#  'B',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'E',
#  'D',
#  'E',
#  'C',
#  'C',
#  'B',
#  'A',
#  'B',
#  'B',
#  'B',
#  'E',
#  'E',
#  'D',
#  'E',
#  'A',
#  'E',
#  'E',
#  'C',
#  'C',
#  'B',
#  'D',
#  'C',
#  'D',
#  'E',
#  'B',
#  'D',
#  'B',
#  'A',
#  'B',
#  'E',
#  'C',
#  'D',
#  'A',
#  'A',
#  'D',
#  'A',
#  'C',
#  'D',
#  'E',
#  'E',
#  'D',
#  'A',
#  'C',
#  'B',
#  'C',
#  'E',
#  'B',
#  'C',
#  'B',
#  'D',
#  'E',
#  'A',
#  'E',
#  'A',
#  'D',
#  'B',
#  'E',
#  'C',
#  'C',
#  'C',
#  'D',
#  'E',
#  'E',
#  'E',
#  'B',
#  'D',
#  'B',
#  'E',
#  'B',
#  'D',
#  'D',
#  'E',
#  'D',
#  'D',
#  'E',
#  'A',
#  'A',
#  'E',
#  'C',
#  'C',
#  'E',
#  'D',
#  'B',
#  'B',
#  'E',
#  'C',
#  'E',
#  'C',
#  'B',
#  'C',
#  'D',
#  'D',
#  'A',
#  'B',
#  'D',
#  'B',
#  'E',
#  'D',
#  'D',
#  'C',
#  'A',
#  'D',
#  'D',
#  'B',
#  'B',
#  'E',
#  'E',
#  'A',
#  'D',
#  'E',
#  'B',
#  'A',
#  'D',
#  'E',
#  'C',
#  'C',
#  'C',
#  'E',
#  'A',
#  'B',
#  'D',
#  'D',
#  'E',
#  'D',
#  'B',
#  'E',
#  'A',
#  'E',
#  'A',
#  'D',
#  'C',
#  'B',
#  'C',
#  'A',
#  'E',
#  'D',
#  'A',
#  'C',
#  'C',
#  'D',
#  'A',
#  'D',
#  'E',
#  'E',
#  'B',
#  'E',
#  'C',
#  'B',
#  'D',
#  'C',
#  'E',
#  'E',
#  'C',
#  'C',
#  'B',
#  'E',
#  'A',
#  'A',
#  'A',
#  'E',
#  'E',
#  'E',
#  'C',
#  'A',
#  'E',
#  'A',
#  'C',
#  'E',
#  'E',
#  'A',
#  'C',
#  'C',
#  'E',
#  'A',
#  'B',
#  'D',
#  'C',
#  'C',
#  'A',
#  'C',
#  'C',
#  'D',
#  'E',
#  'E',
#  'E',
#  'A',
#  'B',
#  'E',
#  'C',
#  'B',
#  'A',
#  'E',
#  'A',
#  'D',
#  'C',
#  'A',
#  'A',
#  'B',
#  'C',
#  'E',
#  'A',
#  'B',
#  'B',
#  'D',
#  'A',
#  'B',
#  'C',
#  'B',
#  'E',
#  'B',
#  'C',
#  'D',
#  'B',
#  'A',
#  'C',
#  'A',
#  'E',
#  'D',
#  'B',
#  'D',
#  'D',
#  'E',
#  'E',
#  'A',
#  'A',
#  'C',
#  'E',
#  'A',
#  'C',
#  'D',
#  'D',
#  'D',
#  'A',
#  'C',
#  'B',
#  'E',
#  'A',
#  'C',
#  'E',
#  'C',
#  'B',
#  'B',
#  'D',
#  'A',
#  'C',
#  'C',
#  'A',
#  'B',
#  'E',
#  'B',
#  'A',
#  'B',
#  'C',
#  'A',
#  'A',
#  'C',
#  'C',
#  'E',
#  'B',
#  'C',
#  'E',
#  'E',
#  'E',
#  'B',
#  'D',
#  'B',
#  'E',
#  'A',
#  'E',
#  'E',
#  'C',
#  'D',
#  'B',
#  'D',
#  'E',
#  'C',
#  'B',
#  'E',
#  'A',
#  'D',
#  'E',
#  'B',
#  'B',
#  'D',
#  'D',
#  'D',
#  'B',
#  'B',
#  'D',
#  'A',
#  'E',
#  'D',
#  'E',
#  'B',
#  'A',
#  'C',
#  'C',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'A',
#  'C',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'E',
#  'B',
#  'B',
#  'E',
#  'E',
#  'D',
#  'D',
#  'A',
#  'D',
#  'E',
#  'B',
#  'B',
#  'B',
#  'B',
#  'A',
#  'B',
#  'B',
#  'C',
#  'C',
#  'B',
#  'D',
#  'D',
#  'E',
#  'B',
#  'B',
#  'C',
#  'C',
#  'A',
#  'C',
#  'C',
#  'B',
#  'B',
#  'C',
#  'B',
#  'A',
#  'A',
#  'B',
#  'B',
#  'E',
#  'A',
#  'D',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'A',
#  'C',
#  'B',
#  'E',
#  'D',
#  'E',
#  'B',
#  'E',
#  'D',
#  'E',
#  'C',
#  'A',
#  'B',
#  'C',
#  'E',
#  'E',
#  'C',
#  'D',
#  'A',
#  'B',
#  'A',
#  'D',
#  'C',
#  'B',
#  'B',
#  'B',
#  'D',
#  'D',
#  'C',
#  'E',
#  'E',
#  'D',
#  'D',
#  'A',
#  'E',
#  'B',
#  'C',
#  'B',
#  'A',
#  'B',
#  'A',
#  'C',
#  'E',
#  'E',
#  'D',
#  'C',
#  'C',
#  'D',
#  'A',
#  'A',
#  'D',
#  'A',
#  'D',
#  'E',
#  'B',
#  'E',
#  'E',
#  'E',
#  'D',
#  'A',
#  'D',
#  'D',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'A',
#  'A',
#  'A',
#  'C',
#  'C',
#  'A',
#  'B',
#  'E',
#  'B',
#  'A',
#  'C',
#  'B',
#  'A',
#  'B',
#  'E',
#  'C',
#  'A',
#  'B',
#  'C',
#  'C',
#  'A',
#  'E',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'D',
#  'D',
#  'C',
#  'E',
#  'B',
#  'D',
#  'D',
#  'D',
#  'B',
#  'E',
#  'C',
#  'C',
#  'B',
#  'A',
#  'D',
#  'D',
#  'C',
#  'A',
#  'D',
#  'C',
#  'B',
#  'C',
#  'B',
#  'D',
#  'B',
#  'A',
#  'B',
#  'D',
#  'D',
#  'C',
#  'A',
#  'D',
#  'E',
#  'A',
#  'A',
#  'B',
#  'A',
#  'E',
#  'B',
#  'C',
#  'A',
#  'B',
#  'D',
#  'E',
#  'C',
#  'D',
#  'D',
#  'D',
#  'C',
#  'B',
#  'D',
#  'A',
#  'B',
#  'A',
#  'C',
#  'A',
#  'B',
#  'B',
#  'C',
#  'E',
#  'B',
#  'B',
#  'D',
#  'A',
#  'D',
#  'C',
#  'A',
#  'E',
#  'A',
#  'E',
#  'D',
#  'C',
#  'C',
#  'D',
#  'A',
#  'A',
#  'C',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'D',
#  'A',
#  'D',
#  'D',
#  'A',
#  'D',
#  'A',
#  'D',
#  'B',
#  'D',
#  'C',
#  'A',
#  'D',
#  'C',
#  'B',
#  'D',
#  'D',
#  'D',
#  'B',
#  'E',
#  'C',
#  'B',
#  'C',
#  'C',
#  'D',
#  'D',
#  'C',
#  'C',
#  'A',
#  'E',
#  'A',
#  'E',
#  'E',
#  'B',
#  'A',
#  'B',
#  'B',
#  'C',
#  'D',
#  'E',
#  'D',
#  'E',
#  'E',
#  'D',
#  'D',
#  'C',
#  'D',
#  'C',
#  'B',
#  'A',
#  'C',
#  'D',
#  'D',
#  'C',
#  'E',
#  'C',
#  'A',
#  'C',
#  'A',
#  'D',
#  'D',
#  'D',
#  'C',
#  'B',
#  'E',
#  'E',
#  'A',
#  'B',
#  'D',
#  'E',
#  'B',
#  'C',
#  'B',
#  'A',
#  'D',
#  'A',
#  'E',
#  'A',
#  'C',
#  'C',
#  'A',
#  'C',
#  'C',
#  'C',
#  'B',
#  'B',
#  'D',
#  'A',
#  'A',
#  'B',
#  'A',
#  'E',
#  'B',
#  'B',
#  'E',
#  'D',
#  'C',
#  'B',
#  'B',
#  'E',
#  'C',
#  'C',
#  'A',
#  'D',
#  'B',
#  'C',
#  'A',
#  'B',
#  'A',
#  'A',
#  'E',
#  'B',
#  'C',
#  'E',
#  'C',
#  'C',
#  'A',
#  'C',
#  'B',
#  'C',
#  'C',
#  'A',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'C',
#  'D',
#  'D',
#  'A',
#  'E',
#  'E',
#  'B',
#  'E',
#  'E',
#  'E',
#  'E',
#  'D',
#  'B',
#  'E',
#  'C',
#  'A',
#  'A',
#  'A',
#  'B',
#  'D',
#  'A',
#  'E',
#  'B',
#  'D',
#  'D',
#  'A',
#  'C',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'D',
#  'E',
#  'D',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'B',
#  'C',
#  'D',
#  'E',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'E',
#  'D',
#  'D',
#  'B',
#  'A',
#  'D',
#  'C',
#  'A',
#  'A',
#  'C',
#  'A',
#  'B',
#  'E',
#  'C',
#  'E',
#  'A',
#  'D',
#  'D',
#  'C',
#  'D',
#  'E',
#  'E',
#  'E',
#  'D',
#  'E',
#  'B',
#  'E',
#  'A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'B',
#  'A',
#  'B',
#  'E',
#  'A',
#  'C',
#  'D',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'D',
#  'D',
#  'D',
#  'E',
#  'A',
#  'E',
#  'D',
#  'C',
#  'E',
#  'E',
#  'D',
#  'A',
#  'A',
#  'B',
#  'D',
#  'A',
#  'B',
#  'E',
#  'A',
#  'E',
#  'C',
#  'C',
#  'D',
#  'A',
#  'D',
#  'D',
#  'E',
#  'C',
#  'A',
#  'C',
#  'E',
#  'B',
#  'E',
#  'B',
#  'B',
#  'E',
#  'C',
#  'A',
#  'B',
#  'B',
#  'E',
#  'D',
#  'C',
#  'E',
#  'E',
#  'C',
#  'B',
#  'A',
#  'C',
#  'B',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'C',
#  'D',
#  'D',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'D',
#  'C',
#  'A',
#  'B',
#  'B',
#  'E',
#  'C',
#  'C',
#  'D',
#  'C',
#  'E',
#  'D',
#  'C',
#  'D',
#  'A',
#  'D',
#  'C',
#  'E',
#  'D',
#  'B',
#  'D',
#  'E',
#  'E',
#  'E',
#  'C',
#  'E',
#  'C',
#  'D',
#  'A',
#  'E',
#  'A',
#  'D',
#  'C',
#  'A',
#  'C',
#  'D',
#  'A',
#  'D',
#  'A',
#  'A',
#  'D',
#  'D',
#  'E',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'D',
#  'E',
#  'C',
#  'D',
#  'B',
#  'A',
#  'A',
#  'D',
#  'C',
#  'A',
#  'D',
#  'C',
#  'D',
#  'C',
#  'A',
#  'A',
#  'A',
#  'C',
#  'D',
#  'E',
#  'C',
#  'A',
#  'B',
#  'A',
#  'E',
#  'B',
#  'C',
#  'C',
#  'A',
#  'A',
#  'D',
#  'E',
#  'B',
#  'E',
#  'C',
#  'E',
#  'A',
#  'C',
#  'C',
#  'B',
#  'A',
#  'A',
#  'B',
#  'E',
#  'D',
#  'E',
#  'A',
#  'B',
#  'D',
#  'E',
#  'D',
#  'B',
#  'E',
#  'B',
#  'D',
#  'A',
#  'D',
#  'D',
#  'B',
#  'E',
#  'A',
#  'E',
#  'B',
#  'C',
#  'C',
#  'A',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'D',
#  'A',
#  'C',
#  'E',
#  'A',
#  'B',
#  'A',
#  'B',
#  'A',
#  'D',
#  'B',
#  'D',
#  'D',
#  'A',
#  'E',
#  'C',
#  'E',
#  'B',
#  'E',
#  'A',
#  'E',
#  'C',
#  'D',
#  'C',
#  ...]
